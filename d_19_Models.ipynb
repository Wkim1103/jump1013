# %% [markdown]
# # 머신러닝 모델 비교
#
# - 서포트벡터머신, 결정 트리, 랜덤 포레스트
# - 교차 검증
# - 모델은 분류(classification)와 회귀에 모두 사용된다
# - WHO 수명 예측 데이터 사용

# %% [markdown]
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-05-30%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.13.52.png?raw=1" align='left'  width=400>

# %% [markdown]
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-05-30%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.15.40.png?raw=1" align='left'  width=500>

# %% [markdown]
# ## 데이터

# %% [markdown]
# ## import

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from warnings import filterwarnings
filterwarnings('ignore')
# %config InlineBackend.figure_format="retina"
matplotlib.rcParams['figure.figsize'] = (8,6)
matplotlib.rcParams.update({'font.size': 15})

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC, SVR
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn import tree
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score            #mean squared error 삭제   
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %% [markdown]
# ## 데이터 읽기

# %%
data = pd.read_csv("https://raw.githubusercontent.com/StillWork/data/master/Life%20Expectancy%20Data.csv")
data = data.dropna()
data.Status = data.Status.map({"Developing":0, "Developed":1})
df = data.copy()
data[:3]
# Out:
#        Country  Year  ...  Income composition of resources  Schooling
# 0  Afghanistan  2015  ...                            0.479       10.1
# 1  Afghanistan  2014  ...                            0.476       10.0
# 2  Afghanistan  2013  ...                            0.470        9.9
#
# [3 rows x 22 columns]

# %% [markdown]
# # 교차검증
# - 훈련/검증 데이터 나누는 작업을 train_test_split을 사용하여 한번만 나누지 않고 전체 데이터를 대상으로 여러번 수행
# - 다양한 조합의 훈련/검증 데이터로 검증함으로써 모델의 성능을 안정적으로 평가
# - cross_val_score 함수를 사용
# - 데이터를 랜덤하게 섞지 않고 아래 그림처럼 나누는 옵션도 있다 (shuffle=False)

# %% [markdown]
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-05-30%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.27.57.png?raw=1" align='left'  width=400>

# %%
def cross_validation(model, X, y, n=5): 
    cv = KFold(n, shuffle=True)
    return cross_val_score(model, X, y, cv=cv).mean().round(4)

# %% [markdown]
# # 회귀 모델
# - 스케일링을 하는 경우

# %%
y = df['Life expectancy ']

features = df.columns.difference(['Country','Life expectancy '])
X = df[features]
cont_features = X.columns.difference(['Status'])
X_sc = X.copy()
X_sc.loc[:,cont_features] = StandardScaler().fit_transform(X_sc[cont_features])
X_train, X_test, y_train, y_test = train_test_split(X_sc, y, random_state=9)

# %%
def show_reg_result(y_test,y_pred):
    print("Max Error: ", 
      round(np.abs(y_test - y_pred).max(),3))
    print("Mean Absolute Error: ", 
      round(np.abs(y_test-y_pred).mean(),3))
    print("Root Mean Squared Error: ", 
      mean_squared_error(y_test,y_pred, squared=False).round(3))
    print("R-Squared: ", 
      r2_score(y_test, y_pred).round(3))

# %%
def plot_feature_weight(feature, weight):
    plt.figure(figsize=(8,8))
    W = pd.DataFrame({'feature':feature,'weight':weight})
    W.sort_values('weight', inplace=True)
    plt.barh(W.feature, W.weight)

# %% [markdown]
# ## 선형 모델

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)

y_pred = linear_reg.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  12.46
# Mean Absolute Error:  2.85
# Root Mean Squared Error:  3.659
# R-Squared:  0.832

# %%
cross_validation(linear_reg,X,y)
# Out:
# 0.8337

# %%
plot_feature_weight(X.columns, linear_reg.coef_)

# %% [markdown]
# ## SVM
# - 스케일링 하지 않으면 잘 동작하지 않는다.

# %%
svr = SVR(kernel="linear")
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  13.951
# Mean Absolute Error:  2.886
# Root Mean Squared Error:  3.762
# R-Squared:  0.822

# %%
# cross_validation(svr,X,y)

# %%
plot_feature_weight(X.columns, svr.coef_[0])

# %% [markdown]
# - SVM 개념
#  - 선형모델을 개선한 모델 (마진이 있는 결정경계 설정)
#  - 학습 샘플수가 적을 때 유용
#  - 다차항을 추가한 커널 기법 도입으로 성능 개선
#
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-05-30%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%209.28.37.png?raw=1" align='left'  width=500>

# %% [markdown]
# ## 결정트리
# - 결정 트리를 회귀모델에 사용할 때는 나누어지는 하위 두 그룹의 분산이 가능한 작아지도록 나눈다
#  - 즉, 회귀 대상의 수치가 가능한 비슷한 샘플들이 모이도록 나눈다
# - 결정 트리를 분류에 사용할 때는 크로스엔트로피 (또는 지니지수)가 가능한 작아지도록 나눈다
#  - 즉, 나누어진 그룹에 같은 그룹의 샘플이 모이는 것을 측정하여 순도(purity)가 가능한 높아지도록 나눈다

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
y_pred = dtr.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  12.8
# Mean Absolute Error:  1.578
# Root Mean Squared Error:  2.59
# R-Squared:  0.916

# %%
cross_validation(dtr,X,y)
# Out:
# 0.919

# %%
plot_feature_weight(X.columns, dtr.feature_importances_)

# %% [markdown]
# - 결정트리 보기

# %%
plt.figure(figsize=(30,15))
# plt.rcParams["figure.dpi"] = 200

tree.plot_tree(dtr, fontsize=10,
              feature_names=X.columns,
              filled=True,
              impurity=True,
              max_depth=2)
plt.show()

# %%
print(tree.export_text(dtr, feature_names=list(X.columns)))
# Out:
# |--- Income composition of resources <= -0.39
# |   |---  HIV/AIDS <= -0.06
# |   |   |--- Adult Mortality <= 0.57
# |   |   |   |---  HIV/AIDS <= -0.22
# |   |   |   |   |--- Schooling <= 0.12
# |   |   |   |   |   |--- percentage expenditure <= -0.39
# |   |   |   |   |   |   |--- Schooling <= -2.03
# |   |   |   |   |   |   |   |--- percentage expenditure <= -0.39
# |   |   |   |   |   |   |   |   |--- value: [61.40]
# |   |   |   |   |   |   |   |--- percentage expenditure >  -0.39
# |   |   |   |   |   |   |   |   |--- value: [56.20]
# |   |   |   |   |   |   |--- Schooling >  -2.03
# |   |   |   |   |   |   |   |--- Measles  <= -0.20
# |   |   |   |   |   |   |   |   |--- Income composition of resources <= -0.75
# |   |   |   |   |   |   |   |   |   |--- GDP <= -0.42
# |   |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years <= -0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years >  -0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--
   |   |   |   |   |   |   |   |   |---  thinness 5-9 years <= -0.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [64.20]
# |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years >  -0.55
# |   |   |   |   |   |   |   |   |   |   |--- Total expenditure <= -0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [63.40]
# |   |   |   |   |   |   |   |   |   |   |--- Total expenditure >  -0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [63.50]
# |   |   |   |   |   |   |   |---  thinness 5-9 years >  0.37
# |   |   |   |   |   |   |   |   |--- Year <= 0.41
# |   |   |   |   |   |   |   |   |   |--- Measles  <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [67.00]
# |   |   |   |   |   |   |   |   |   |--- Measles  >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [64.70]
# |   |   |   |   |   |   |   |   |--- Year >  0.41
# |   |   |   |   |   |   |   |   |   |--- GDP <= -0.37
# |   |   |   |   |   |   |   |   |   |   |--- value: [69.00]
# |   |   |   |   |   |   |   |   |   |--- GDP >  -0.37
# |   |   |   |   |   |   |   |   |   |   |--- value: [67.90]
# |   |   |   |   |--- Schooling >  0.12
# |   |   |   |   |   |--- Schooling <= 0.35
# |   |   |   |   |   |   |--- value: [75.00]
# |   |   |   |   |   |--- Schooling >  0.35
# |   |   |   |   |   |   |---  BMI  <= -0.29
# |   |   |   |   |   |   |   |--- value: [73.90]
# |   |   |   |   |   |   |---  BMI  >  -0.29
# |   |   |   |   |   |   |   |--- Adult Mortality <= -0.83
# |   |   |   |   |   |   |   |   |--- value: [73.20]
# |   |   |   |   |   |   |   |--- Adult Mortality >  -0.83
# |   |   |   |   |   |   |   |   |--- value: [72.70]
# |   |   |   |---  HIV/AIDS >  -0.22
# |   |   |   |   |--- Income composition of resources <= -1.14
# |   |   |   |   |   |---  BMI  <= -0.87
# |   |   |   |   |   |   |--- Population <= -0.11
# |   |   |   |   |   |   |   |--- Alcohol <= -0.99
# |   |   |   |   |   |   |   |   |--- value: [58.60]
# |   |   |   |   |   |   |   |--- Alcohol >  -0.99
# |   |   |   |   |   |   |   |   |--- under-five deaths  <= -0.04
# |   |   |   |   |   |   |   |   |   |--- value: [59.40]
# |   |   |   |   |   |   |   |   |--- under-five deaths  >  -0.04
# |   |   |   |   |   |   |   |   |   |--- value: [59.00]
# |   |   |   |   |   |   |--- Population >  -0.11
# |   |   |   |   |   |   |   |--- Population <= -0.00
# |   |   |   |   |   |   |   |   |--- value: [61.30]
# |   |   |   |   |   |   |   |--- Population >  -0.00
# |   |   |   |   |   |   |   |   |--- value: [63.00]
# |   |   |   |   |   |---  BMI  >  -0.87
# |   |   |   |   |   |   |--- Hepatitis B <= -0.01
# |   |   |   |   |   |   |   |--- value: [57.20]
# |   |   |   |   |   |   |--- Hepatitis B >  -0.01
# |   |   |   |   |   |   |   |--- value: [54.00]
# |   |   |   |   |--- Income composition of resources >  -1.14
# |   |   |   |   |   |--- Year <= -1.43
# |   |   |   |   |   |   |--- value: [71.30]
# |   |   |   |   |   |--- Year >  -1.43
# |   |   |   |   |   |   |---  thinness 5-9 years <= 0.93
# |   |   |   |   |   |   |   |--- Polio <= 0.44
# |   |   |   |   |   |   |   |   |--- Income composition of resources <= -0.78
# |   |   |   |   |   |   |   |   |   |--- Population <= -0.16
# |   |   |   |   |   |   |   |   |   |   |---  HIV/AIDS <= -0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value:
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [44.80]
# |   |   |   |   |   |   |   |--- Year >  -0.33
# |   |   |   |   |   |   |   |   |--- Hepatitis B <= -1.51
# |   |   |   |   |   |   |   |   |   |--- value: [46.20]
# |   |   |   |   |   |   |   |   |--- Hepatitis B >  -1.51
# |   |   |   |   |   |   |   |   |   |--- value: [46.60]
# |   |   |   |   |   |   |--- Total expenditure >  1.18
# |   |   |   |   |   |   |   |--- Schooling <= -0.70
# |   |   |   |   |   |   |   |   |--- value: [47.10]
# |   |   |   |   |   |   |   |--- Schooling >  -0.70
# |   |   |   |   |   |   |   |   |--- value: [47.80]
# |   |   |   |   |   |--- Income composition of resources >  -0.73
# |   |   |   |   |   |   |--- percentage expenditure <= -0.35
# |   |   |   |   |   |   |   |--- Polio <= 0.18
# |   |   |   |   |   |   |   |   |--- value: [48.40]
# |   |   |   |   |   |   |   |--- Polio >  0.18
# |   |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |   |--- percentage expenditure >  -0.35
# |   |   |   |   |   |   |   |--- Adult Mortality <= 3.18
# |   |   |   |   |   |   |   |   |--- value: [47.80]
# |   |   |   |   |   |   |   |--- Adult Mortality >  3.18
# |   |   |   |   |   |   |   |   |--- Diphtheria  <= 0.02
# |   |   |   |   |   |   |   |   |   |--- value: [47.10]
# |   |   |   |   |   |   |   |   |--- Diphtheria  >  0.02
# |   |   |   |   |   |   |   |   |   |--- Hepatitis B <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- value: [46.70]
# |   |   |   |   |   |   |   |   |   |--- Hepatitis B >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- value: [46.40]
# |   |   |   |---  BMI  >  -0.47
# |   |   |   |   |--- Hepatitis B <= 0.42
# |   |   |   |   |   |--- Adult Mortality <= 2.39
# |   |   |   |   |   |   |--- Alcohol <= 0.09
# |   |   |   |   |   |   |   |--- value: [52.60]
# |   |   |   |   |   |   |--- Alcohol >  0.09
# |   |   |   |   |   |   |   |--- value: [53.60]
# |   |   |   |   |   |--- Adult Mortality >  2.39
# |   |   |   |   |   |   |--- value: [51.40]
# |   |   |   |   |--- Hepatitis B >  0.42
# |   |   |   |   |   |--- value: [49.40]
# |--- Income composition of resources >  -0.39
# |   |--- Income composition of resources <= 0.92
# |   |   |--- Adult Mortality <= 0.35
# |   |   |   |--- Adult Mortality <= -0.12
# |   |   |   |   |--- Total expenditure <= -0.11
# |   |   |   |   |   |--- Adult Mortality <= -0.86
# |   |   |   |   |   |   |--- Adult Mortality <= -1.20
# |   |   |   |   |   |   |   |--- Alcohol <= 1.15
# |   |   |   |   |   |   |   |   |--- Schooling <= 0.03
# |   |   |   |   |   |   |   |   |   |--- Total expenditure <= -0.33
# |   |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years <= -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years >  -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Total expenditure >  -0.33
# |   |   |   |   |   |   |   |   |   |   |--- Year <= -1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [72.00]
# |   |   |   |   |   |   |   |   |   |   |--- Year >  -1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Schooling >  0.03
# |   |   |   |   |   |   |   |   |   |--- Total expenditure <= -0.20
# |   |   |   |   |   |   |   |   |   |   |--- infant deaths <= -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- infant deaths >  -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Total expenditure >  -0.20
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [74.00]
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- Alcohol >  1.15
# |   |   |   |   |   |   |   |   |--- value: [66.40]
# |   |   |   |   |   |   |--- Adult Mortality >  -1.20
# |   |   |   |   |   |   |   |--- Adult Mortality <= -1.10
# |   |   |   |   |   |   |   |   |---  thinness 5-9 years <= -0.53
# |   |   |   |   |   |   |   |   |   |--- infant deaths <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- under-five deaths  <= -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- under-five deaths  >  -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- infant deaths >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- percentage expenditure <= -0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [67.20]
# |   |   |   |   |   |   |   |   |   |   |--- percentage expenditure >  -0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [67.50]
# |   |   |   |   |   |   |   |   |---  thinness 5-9 years >  -0.53
# |   |   |   |   |   |   |   |   |   |--- Total expenditure <= -0.30
# |   |   |   |   |   |   |   |   |   |   |--- Income composition of resources <= 0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Income composition of resources >  0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Total expenditure >  -0.30
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= -2.07
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [71.60]
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  -2.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Adult Mortality >  -1.10
# |   |   |   |   |   |   |   |   |--- Year <= -0.21
# |   |   |   |   |   |   |   |   |   |--- infant deaths <= -0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [65.00]
# |   |   |   |   |   |   |   |   |   |--- infant deaths >  -0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [65.10]
# |   |   |   |   |   |   |   |   |--- Year >  -0.21
# |   |   |   |   |   |   |   |   |   |--- Year <= 0.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [61.70]
# |   |   |   |   |   |   |   |   |   |--- Year >  0.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [57.90]
# |   |   |   |   |   |--- Adult Mortality >  -0.86
# |   |   |   |   |   |   |--- Income composition of resources <= 0.33
# |   |   |   |   |   |   |   |--- Income composition of resources <= -0.34
# |   |   |   |   |   |   |   |   |--- GDP <= -0.34
# |   |   |   |   |   |   |   |   |   |--- value: [77.00]
# |   |   |   |   |   |   |   |   |--- GDP >  -0.34
# |   |   |   |   |   |   |   |   |   |--- value: [72.00]
# ...
# |   |   |   |   |   |   |   |   |   |--- value: [77.10]
# |   |   |   |   |   |   |   |--- Adult Mortality >  -1.22
# |   |   |   |   |   |   |   |   |---  BMI  <= -1.61
# |   |   |   |   |   |   |   |   |   |--- value: [76.30]
# |   |   |   |   |   |   |   |   |---  BMI  >  -1.61
# |   |   |   |   |   |   |   |   |   |--- value: [76.60]
# |   |   |   |   |   |   |--- Schooling >  0.98
# |   |   |   |   |   |   |   |--- Population <= 0.39
# |   |   |   |   |   |   |   |   |--- Income composition of resources <= 0.97
# |   |   |   |   |   |   |   |   |   |--- value: [75.90]
# |   |   |   |   |   |   |   |   |--- Income composition of resources >  0.97
# |   |   |   |   |   |   |   |   |   |--- value: [75.70]
# |   |   |   |   |   |   |   |--- Population >  0.39
# |   |   |   |   |   |   |   |   |--- Total expenditure <= -0.46
# |   |   |   |   |   |   |   |   |   |--- value: [76.20]
# |   |   |   |   |   |   |   |   |--- Total expenditure >  -0.46
# |   |   |   |   |   |   |   |   |   |--- value: [76.00]
# |   |   |   |   |   |---  BMI  >  1.23
# |   |   |   |   |   |   |--- Hepatitis B <= 0.64
# |   |   |   |   |   |   |   |--- value: [77.80]
# |   |   |   |   |   |   |--- Hepatitis B >  0.64
# |   |   |   |   |   |   |   |--- value: [77.70]
# |   |   |   |--- Income composition of resources >  1.06
# |   |   |   |   |--- Year <= -1.06
# |   |   |   |   |   |--- Schooling <= 3.02
# |   |   |   |   |   |   |---  thinness 5-9 years <= -0.89
# |   |   |   |   |   |   |   |--- Population <= 0.13
# |   |   |   |   |   |   |   |   |---  BMI  <= 0.91
# |   |   |   |   |   |   |   |   |   |--- Population <= -0.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.70]
# |   |   |   |   |   |   |   |   |   |--- Population >  -0.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.80]
# |   |   |   |   |   |   |   |   |---  BMI  >  0.91
# |   |   |   |   |   |   |   |   |   |---  BMI  <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [80.00]
# |   |   |   |   |   |   |   |   |   |---  BMI  >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.90]
# |   |   |   |   |   |   |   |--- Population >  0.13
# |   |   |   |   |   |   |   |   |---  BMI  <= 0.89
# |   |   |   |   |   |   |   |   |   |--- value: [79.00]
# |   |   |   |   |   |   |   |   |---  BMI  >  0.89
# |   |   |   |   |   |   |   |   |   |--- under-five deaths  <= -0.25
# |   |   |   |   |   |   |   |   |   |   |--- Measles  <= -0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [79.50]
# |   |   |   |   |   |   |   |   |   |   |--- Measles  >  -0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [79.40]
# |   |   |   |   |   |   |   |   |   |--- under-five deaths  >  -0.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.30]
# |   |   |   |   |   |   |---  thinness 5-9 years >  -0.89
# |   |   |   |   |   |   |   |--- Polio <= 0.44
# |   |   |   |   |   |   |   |   |--- Income composition of resources <= 1.19
# |   |   |   |   |   |   |   |   |   |--- Hepatitis B <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- Population <= -0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.60]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  -0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.70]
# |   |   |   |   |   |   |   |   |   |--- Hepatitis B >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- Income composition of resources <= 1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.80]
# |   |   |   |   |   |   |   |   |   |   |--- Income composition of resources >  1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.90]
# |   |   |   |   |   |   |   |   |--- Income composition of resources >  1.19
# |   |   |   |   |   |   |   |   |   |--- Total expenditure <= 0.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.70]
# |   |   |   |   |   |   |   |   |   |--- Total expenditure >  0.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.30]
# |   |   |   |   |   |   |   |--- Polio >  0.44
# |   |   |   |   |   |   |   |   |--- Year <= -1.55
# |   |   |   |   |   |   |   |   |   |--- Population <= -0.21
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [77.60]
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [77.80]
# |   |   |   |   |   |   |   |   |   |--- Population >  -0.21
# |   |   |   |   |   |   |   |   |   |   |--- Measles  <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.00]
# |   |   |   |   |   |   |   |   |   |   |--- Measles  >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.30]
# |   |   |   |   |   |   |   |   |--- Year >  -1.55
# |   |   |   |   |   |   |   |   |   |--- Year <= -1.31
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= 0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.40]
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.30]
# |   |   |   |   |   |   |   |   |   |--- Year >  -1.31
# |   |   |   |   |   |   |   |   |   |   |--- Diphtheria  <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78.50]
# |   |   |   |   |   |   |   |   |   |   |--- Diphtheria  >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [78
.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- Adult Mortality >  -0.70
# |   |   |   |   |   |   |--- percentage expenditure <= -0.36
# |   |   |   |   |   |   |   |--- value: [89.00]
# |   |   |   |   |   |   |--- percentage expenditure >  -0.36
# |   |   |   |   |   |   |   |---  thinness  1-19 years <= -0.90
# |   |   |   |   |   |   |   |   |--- percentage expenditure <= 2.77
# |   |   |   |   |   |   |   |   |   |--- GDP <= 2.51
# |   |   |   |   |   |   |   |   |   |   |--- Alcohol <= 1.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Alcohol >  1.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- GDP >  2.51
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.00]
# |   |   |   |   |   |   |   |   |--- percentage expenditure >  2.77
# |   |   |   |   |   |   |   |   |   |---  BMI  <= 1.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [86.00]
# |   |   |   |   |   |   |   |   |   |---  BMI  >  1.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.00]
# |   |   |   |   |   |   |   |---  thinness  1-19 years >  -0.90
# |   |   |   |   |   |   |   |   |---  BMI  <= 1.22
# |   |   |   |   |   |   |   |   |   |--- Year <= -0.57
# |   |   |   |   |   |   |   |   |   |   |--- Adult Mortality <= -0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Adult Mortality >  -0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Year >  -0.57
# |   |   |   |   |   |   |   |   |   |   |--- Polio <= 0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Polio >  0.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |---  BMI  >  1.22
# |   |   |   |   |   |   |   |   |   |--- percentage expenditure <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.00]
# |   |   |   |   |   |   |   |   |   |--- percentage expenditure >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.00]
# |   |   |---  thinness  1-19 years >  -0.65
# |   |   |   |--- Income composition of resources <= 1.09
# |   |   |   |   |--- GDP <= 0.43
# |   |   |   |   |   |--- Total expenditure <= 0.08
# |   |   |   |   |   |   |--- Polio <= 0.44
# |   |   |   |   |   |   |   |--- value: [73.60]
# |   |   |   |   |   |   |--- Polio >  0.44
# |   |   |   |   |   |   |   |--- Year <= -0.82
# |   |   |   |   |   |   |   |   |--- value: [72.30]
# |   |   |   |   |   |   |   |--- Year >  -0.82
# |   |   |   |   |   |   |   |   |--- value: [72.80]
# |   |   |   |   |   |--- Total expenditure >  0.08
# |   |   |   |   |   |   |--- Hepatitis B <= 0.52
# |   |   |   |   |   |   |   |--- value: [78.00]
# |   |   |   |   |   |   |--- Hepatitis B >  0.52
# |   |   |   |   |   |   |   |--- Alcohol <= 1.80
# |   |   |   |   |   |   |   |   |--- Hepatitis B <= 0.66
# |   |   |   |   |   |   |   |   |   |--- value: [75.00]
# |   |   |   |   |   |   |   |   |--- Hepatitis B >  0.66
# |   |   |   |   |   |   |   |   |   |--- Measles  <= -0.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [75.30]
# |   |   |   |   |   |   |   |   |   |--- Measles  >  -0.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [75.20]
# |   |   |   |   |   |   |   |--- Alcohol >  1.80
# |   |   |   |   |   |   |   |   |--- value: [76.00]
# |   |   |   |   |--- GDP >  0.43
# |   |   |   |   |   |--- Alcohol <= 0.09
# |   |   |   |   |   |   |--- value: [74.40]
# |   |   |   |   |   |--- Alcohol >  0.09
# |   |   |   |   |   |   |---  thinness  1-19 years <= -0.44
# |   |   |   |   |   |   |   |--- Schooling <= 1.46
# |   |   |   |   |   |   |   |   |--- Status <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [73.00]
# |   |   |   |   |   |   |   |   |--- Status >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [72.80]
# |   |   |   |   |   |   |   |--- Schooling >  1.46
# |   |   |   |   |   |   |   |   |--- Diphtheria  <= 0.43
# |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years <= -0.46
# |   |   |   |   |   |   |   |   |   |   |--- value: [73.00]
# |   |   |   |   |   |   |   |   |   |---  thinness 5-9 years >  -0.46
# |   |   |   |   |   |   |   |   |   |   |--- value: [72.80]
# |   |   |   |   |   |   |   |   |--- Diphtheria  >  0.43
# |   |   |   |   |   |   |   |   |   |--- GDP <= 0.75
# |   |   |   |   |   |   |   |   |   |   |--- Population <= -0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [72.40]
# |   |   |   |   |   |   |   |   |   |   |--- Population >  -0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [72.20]
# |   |   |   |   |   |   |   |   |   |--- GDP >  0.75
# |   |   |   |   |   |   |   |   |   |   |--- value: [71.90]
# |   |   |   |   |   |   |---  thinness  1-19 years >  -0.44
# |   |   |   |   |   |   |   |--- Schooling <= 1.55
# |   |   |   |   |   |   |   |   |--- value: [72.00]
# |   |   |   |   |   |   |   |--- Schooling >  1.55
# |   |   |   |   |   |   |   |   |--- value: [71.10]
# |   |   |   |--- Income composition of resources >  1.09
# |   |   |   |   |--- Alcohol <= 2.60
# |   |   |   |   |   |--- Adult Mortality <= -0.31
# |   |   |   |   |   |   |--- Hepatitis B <= 0.68
# |   |   |   |   |   |   |   |--- Hepatitis B <= 0.60
# |   |   |   |   |   |   |   |   |--- value: [77.30]
# |   |   |   |   |   |   |   |--- Hepatitis B >  0.60
# |   |   |   |   |   |   |   |   |--- value: [77.10]
# |   |   |   |   |   |   |--- Hepatitis B >  0.68
# |   |   |   |   |   |   |   |--- value: [76.80]
# |   |   |   |   |   |--- Adult Mortality >  -0.31
# |   |   |   |   |   |   |--- Alcohol <= 0.73
# |   |   |   |   |   |   |   |--- Polio <= 0.44
# |   |   |   |   |   |   |   |   |--- value: [76.10]
# |   |   |   |   |   |   |   |--- Polio >  0.44
# |   |   |   |   |   |   |   |   |--- value: [76.30]
# |   |   |   |   |   |   |--- Alcohol >  0.73
# |   |   |   |   |   |   |   |--- value: [75.60]
# |   |   |   |   |--- Alcohol >  2.60
# |   |   |   |   |   |--- Status <= 0.50
# |   |   |   |   |   |   |--- Adult Mortality <= -0.05
# |   |   |   |   |   |   |   |--- value: [74.90]
# |   |   |   |   |   |   |--- Adult Mortality >  -0.05
# |   |   |   |   |   |   |   |--- value: [74.20]
# |   |   |   |   |   |--- Status >  0.50
# |   |   |   |   |   |   |--- value: [73.40]

# %% [markdown]
# ## 랜덤 포레스트

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  8.616
# Mean Absolute Error:  1.218
# Root Mean Squared Error:  1.914
# R-Squared:  0.954

# %%
cross_validation(rfr,X,y)
# Out:
# 0.9557

# %%
plot_feature_weight(X.columns, rfr.feature_importances_)

# %% [markdown]
# ## 랜덤 포레스트 개념
# - 결정 트리의 성능을 개선한 방법
# - 간단한 구조의 결정 트리(weak learner)를 수십~수백개를 만들고 각 결정 트리의 동작 결과의 평균치를 구하는 방법
# - 앙상블(ensemble) 방법이 하나의 모델만 만드는 것보다 좋은 성능을 보인다
# - 각 결정 트리를 만들 때 훈련 데이터의 일부만 사용하거나 특성의 일부를 무작위로 선택하여 만든다

# %% [markdown]
# - 랜덤 포레스트 개념
#
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.13.52.png?raw=1" align='left'  width=400>

# %% [markdown]
# - 소프트 투표
#
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.52.18.png?raw=1" align='left'  width=400>

# %% [markdown]
# ## 부스팅 (LightGBM)
#
# - 아래와 같이 설치해야 함
# - !conda install lightgbm -y

# %%
lgbm_r = LGBMRegressor()
lgbm_r.fit(X_train, y_train, eval_set=(X_test, y_test), 
           early_stopping_rounds=5, verbose=False)
y_pred = lgbm_r.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  13.601
# Mean Absolute Error:  1.198
# Root Mean Squared Error:  1.98
# R-Squared:  0.951

# %%
cross_validation(lgbm_r,X,y)
# Out:
# 0.9575

# %%
plot_feature_weight(X.columns, lgbm_r.feature_importances_)

# %% [markdown]
# ## (예제) 스케일링 하지 않으면 성능이 달라지는지 확인해보시오
# - 입력 데이터를 스케일링 한 경우와 하지 않은 경우의 성능을 비교하시오
# - 성능에 변화가 있는 모델은 어떤 모델인가?

# %%
# (풀이)
y = df['Life expectancy ']

features = df.columns.difference(['Country','Life expectancy '])
X = df[features]
cont_features = X.columns.difference(['Status'])
#X_sc = X.copy()
X.loc[:,cont_features] = StandardScaler().fit_transform(X[cont_features])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=9)


lgbm_r = LGBMRegressor()
lgbm_r.fit(X_train, y_train, eval_set=(X_test, y_test), 
           early_stopping_rounds=5, verbose=False)
y_pred = lgbm_r.predict(X_test)
show_reg_result(y_test,y_pred)
# Out:
# Max Error:  13.601
# Mean Absolute Error:  1.198
# Root Mean Squared Error:  1.98
# R-Squared:  0.951

# %% [markdown]
# # 분류 모델

# %% [markdown]
# ## 손실함수
#
# ### 엔트로피
#
# - 확률 p인 사건의 가치:  $log$(${1}\over{p}$)
# - 엔트로피=확률x기대치: $Entropy(H)$ = $p$ $log$(${1}\over{p}$)
#
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%208.32.23.png?raw=1" align='left'  width=200>

# %% [markdown]
# ### 크로스 엔트로피
#
# - 분류에서 손실함수, 즉 학습을 하면서 줄여야 할 대상 값은 크로스 엔트로피를 사용한다
# - 분류가 잘 수행될수록 (즉, 분류된 하위 그룹의 p가 1 또는 0으로 수렴할수록) 크로스 엔트로피의 합은 점차 줄어들며 이를 분류의 손실함수로 사용한다
# - 계산량을 줄이기 위해서 크로스 엔트로피 대신 gini 계수를 주로 사용한다 (디폴트 값)
#
# <img  src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.13.11.png?raw=1" align='left'  width=400>

# %% [markdown]
# - 크로스 엔트로피:
#
# <img src="https://github.com/StillWork/image/blob/main/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-14%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%208.29.58.png?raw=1" align='left'  width=150>

# %% [markdown]
# - gini 계수:
#
# $1 - \sum {p_{i}}^2$

# %% [markdown]
# ## 특성 중요도
# - 결정트리, 랜덤포레스트, 부스팅 등 트리계열 모델에서 모델의 동작에 기여한 특성별 점수를 알려준다 (합이 1이 되는 수치로 환산)

# %% [markdown]
# ## 분류: 개발 도상국인지를 분류 예측

# %%
y = df['Status']

features = df.columns.difference(['Country','Status'])
X = df[features]
X[:3]
# Out:
#     BMI    HIV/AIDS  ...  percentage expenditure  under-five deaths
# 0   19.1        0.1  ...               71.279624                  83
# 1   18.6        0.1  ...               73.523582                  86
# 2   18.1        0.1  ...               73.219243                  89
#
# [3 rows x 20 columns]

# %%
# cont_features = X.columns.difference(['Status'])
X_sc = X.copy()
X_sc.loc[:,:] = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_sc, y)

# %% [markdown]
# ## 선형 모델

# %%
lin = SGDClassifier() # (1) 모델 생성
lin.fit(X_train, y_train) # (2) 훈련
lin.score(X_test, y_test) # (3) 평가 (정확도)
# Out:
# 0.9297820823244553

# %%
cross_validation(lin,X,y)
# Out:
# 0.8102

# %%
plot_feature_weight(X.columns, lin.coef_[0])

# %% [markdown]
# ## SVM

# %%
# svc = SVC(kernel="linear")
# svc.fit(X_train, y_train)
# svc.score(X_test, y_test)

# %%
# cross_validation(svc,X,y)

# %%
# plot_feature_weight(X.columns, svc.coef_[0])

# %% [markdown]
# ## 결정 트리

# %%
dtc = DecisionTreeClassifier() # (1) 모델 생성
dtc.fit(X_train, y_train) # (2) 훈련
dtc.score(X_test, y_test) # (3) 평가 (정확도)
# Out:
# 0.9661016949152542

# %%
cross_validation(dtc,X,y)
# Out:
# 0.9715

# %%
plot_feature_weight(X.columns, dtc.feature_importances_)

# %%
def show_clf_result(y_test, y_pred):
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))

# %%
y_pred = dtc.predict(X_test)
show_clf_result(y_test, y_pred)
# Out:
# [[344   9]
#  [  5  55]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       353
#            1       0.86      0.92      0.89        60
#
#     accuracy                           0.97       413
#    macro avg       0.92      0.95      0.93       413
# weighted avg       0.97      0.97      0.97       413

# %% [markdown]
# - 결정 트리 보기

# %%
from sklearn import tree
import matplotlib
plt.figure(figsize=(20,10))
# plt.rcParams["figure.dpi"] = 200

tree.plot_tree(dtc, fontsize=10,
              feature_names=X.columns,
              filled=True,
              impurity=True,
              max_depth=2)
plt.show()

# %%
print(tree.export_text(dtc, feature_names=list(X.columns)))
# Out:
# |--- Income composition of resources <= 0.79
# |   |--- Alcohol <= 1.31
# |   |   |--- Alcohol <= 0.78
# |   |   |   |--- Alcohol <= 0.64
# |   |   |   |   |--- class: 0
# |   |   |   |--- Alcohol >  0.64
# |   |   |   |   |--- Alcohol <= 0.65
# |   |   |   |   |   |--- GDP <= -0.20
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- GDP >  -0.20
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Alcohol >  0.65
# |   |   |   |   |   |--- class: 0
# |   |   |--- Alcohol >  0.78
# |   |   |   |--- Hepatitis B <= 0.71
# |   |   |   |   |--- Year <= -1.67
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Year >  -1.67
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Hepatitis B >  0.71
# |   |   |   |   |--- Total expenditure <= -0.59
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Total expenditure >  -0.59
# |   |   |   |   |   |--- class: 1
# |   |--- Alcohol >  1.31
# |   |   |--- Life expectancy  <= 0.15
# |   |   |   |--- class: 0
# |   |   |--- Life expectancy  >  0.15
# |   |   |   |---  thinness  1-19 years <= 0.04
# |   |   |   |   |--- class: 1
# |   |   |   |---  thinness  1-19 years >  0.04
# |   |   |   |   |--- class: 0
# |--- Income composition of resources >  0.79
# |   |--- Alcohol <= 0.95
# |   |   |--- Adult Mortality <= -0.80
# |   |   |   |--- Total expenditure <= 0.90
# |   |   |   |   |--- Polio <= 0.67
# |   |   |   |   |   |--- Income composition of resources <= 1.56
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Income composition of resources >  1.56
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Polio >  0.67
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Total expenditure >  0.90
# |   |   |   |   |--- class: 1
# |   |   |--- Adult Mortality >  -0.80
# |   |   |   |--- Adult Mortality <= -0.23
# |   |   |   |   |--- Schooling <= 0.82
# |   |   |   |   |   |---  BMI  <= 0.69
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |---  BMI  >  0.69
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Schooling >  0.82
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Adult Mortality >  -0.23
# |   |   |   |   |--- Measles  <= -0.22
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Measles  >  -0.22
# |   |   |   |   |   |--- class: 1
# |   |--- Alcohol >  0.95
# |   |   |--- Alcohol <= 2.21
# |   |   |   |--- infant deaths <= -0.25
# |   |   |   |   |--- Alcohol <= 1.24
# |   |   |   |   |   |--- Adult Mortality <= -0.75
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Adult Mortality >  -0.75
# |   |   |   |   |   |   |--- Income composition of resources <= 0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Income composition of resources >  0.92
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Alcohol >  1.24
# |   |   |   |   |   |---  BMI  <= -1.60
# |   |   |   |   |   |   |--- Alcohol <= 1.35
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Alcohol >  1.35
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |---  BMI  >  -1.60
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- infant deaths >  -0.25
# |   |   |   |   |--- Life expectancy  <= 1.28
# |   |   |   |   |   |--- infant deaths <= -0.20
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- infant deaths >  -0.20
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Life expectancy  >  1.28
# |   |   |   |   |   |--- class: 0
# |   |   |--- Alcohol >  2.21
# |   |   |   |--- class: 0

# %% [markdown]
# ## 랜덤 포레스트

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train) 
rfc.score(X_test, y_test).round(4)
# Out:
# 0.9758

# %%
cross_validation(rfc,X,y)
# Out:
# 0.9842

# %%
y_pred = rfc.predict(X_test)
show_clf_result(y_test, y_pred)
# Out:
# [[347   6]
#  [  4  56]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       353
#            1       0.90      0.93      0.92        60
#
#     accuracy                           0.98       413
#    macro avg       0.95      0.96      0.95       413
# weighted avg       0.98      0.98      0.98       413

# %%
plot_feature_weight(X.columns, rfc.feature_importances_)

# %% [markdown]
# ## 부스팅 (LightGBM)

# %%
lgbm_c = LGBMClassifier()
lgbm_c.fit(X_train, y_train, eval_set=(X_test, y_test), 
           early_stopping_rounds=5, verbose=False)
lgbm_c.score(X_test, y_test)
# Out:
# 0.9830508474576272

# %%
cross_validation(lgbm_c,X,y)
# Out:
# 0.9897

# %%
y_pred = lgbm_c.predict(X_test)
show_clf_result(y_test, y_pred)
# Out:
# [[350   3]
#  [  4  56]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       353
#            1       0.95      0.93      0.94        60
#
#     accuracy                           0.98       413
#    macro avg       0.97      0.96      0.97       413
# weighted avg       0.98      0.98      0.98       413

# %% [markdown]
# ## 오분류된 샘플 찾기

# %% [markdown]
# - 0(개발도상국)을 1(개발국)으로 잘 못 분류한 경우

# %%
index_false = X_test[y_test < y_pred].index
print(index_false.size)
df.loc[index_false]
# Out:
# 3
#       Country  Year  ...  Income composition of resources  Schooling
# 1031   Greece  2010  ...                            0.859       16.4
# 226   Belarus  2013  ...                            0.796       15.7
# 1036   Greece  2005  ...                            0.839       15.6
#
# [3 rows x 22 columns]

# %% [markdown]
# ## (연습) 개발국을 개발도상국으로 잘 못 분류한 경우

# %%
# (풀이)
index_false = X_test[y_test > y_pred].index
print(index_false.size)
df.loc[index_false]
# Out:
# 4
#         Country  Year  ...  Income composition of resources  Schooling
# 1644      Malta  2005  ...                            0.805       14.8
# 1456     Latvia  2001  ...                            0.728       14.2
# 126   Australia  2001  ...                            0.899       20.5
# 1283      Italy  2014  ...                            0.877       16.3
#
# [4 rows x 22 columns]

# %% [markdown]
# # 정답

# %% [markdown]
# ## (예제) 스케일링 하지 않으면 성능이 달라지는지 확인해보시오
# - 입력 데이터를 스케일링 한 경우와 하지 않은 경우의 성능을 비교하시오
# - 성능에 변화가 있는 모델은 어떤 모델인가?

# %%
# 스케일링 하지 않는 X 사용하려면 train_test_split에서 X_sc 대신 X를 사용하면 된다
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=9)

# %% [markdown]
# ## (연습) 개발국을 개발도상국으로 잘 못 분류한 경우

# %%
index_false = X_test[y_test > y_pred].index
df.loc[index_false]
# Out:
#         Country  Year  Status  Life expectancy   Adult Mortality  \
# 1523  Lithuania  2014       1              73.4            169.0
# 1456     Latvia  2001       1              69.9            228.0
# 2067   Portugal  2003       1              77.3             15.0
# 2120    Romania  2014       1              74.8            135.0
# 1525  Lithuania  2012       1              73.0            176.0
# 1524  Lithuania  2013       1              73.0            178.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1523              0    15.19             2211.744178         94.0        11
# 1456              0     6.68              332.275171         96.0         1
# 2067              0    14.21             2283.891796         94.0         8
# 2120              2     0.01                1.576409         94.0        59
# 1525              0    15.14             1807.071336         93.0         0
# 1524              0    15.04             1968.816817         93.0        35
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 1523  ...   93.0               6.55         93.0        0.1  16554.97139
# 1456  ...   97.0               6.17         97.0        0.1   3572.85130
# 2067  ...   96.0               9.54         99.0        0.1  15772.73340
# 2120  ...   94.0               5.57         94.0        0.1     12.27733
# 1525  ...   93.0               6.67         93.0        0.1  14341.83600
# 1524  ...   93.0               6.59         93.0        0.1  15712.82376
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 1523   2932367.0                    2.6                  2.7
# 1456    233717.0                    2.8                  2.8
# 2067   1458821.0                    0.7                  0.6
# 2120   1998979.0                    2.6                  2.8
# 1525   2987773.0                    2.7                  2.7
# 1524   2957689.0                    2.7                  2.7
#
#       Income composition of resources  Schooling
# 1523                            0.841       16.5
# 1456                            0.728       14.2
# 2067                            0.789       15.8
# 2120                            0.797       14.7
# 1525                            0.830       16.5
# 1524                            0.834       16.4
#
# [6 rows x 22 columns]
